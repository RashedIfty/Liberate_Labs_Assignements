# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# %%
text = "What is Large Language Model?"
encoded_input = tokenizer.encode(text, return_tensors='pt')

# %%
encoded_input
# Out:
# tensor([[ 2061,   318, 13601, 15417,  9104,    30]])

# %%
tokenizer.decode(encoded_input[0])
# Out:
# 'What is Large Language Model?'

# %%
output = model.generate(encoded_input, max_length=500,num_beams=5,no_repeat_ngram_size=2,early_stopping=True)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
output
# Out:
# tensor([[ 2061,   318, 13601, 15417,  9104,    30,   198,   198,    32,  1588,
#           3303,  2746,   357,  5805,    44,     8,   318,   257,   900,   286,
#           3173,   326,  6901,   703,   257,  3303,   815, 17438,   287,   257,
#           1813,  4732,    13, 10373, 10128,   389,  1690,   973,   284,  6901,
#            262,  4069,   286,  8950,    11,   475,   484,   460,   635,   307,
#            973,   329,   584,  4959,    13,  1114,  1672,    11,   611,   345,
#            765,   284,   760,   703,   284,  3551,   257,  6827,   287,  3594,
#             11,   345,   460,   779,   257, 10373,    44,   326,  8477,   703,
#            262,  6827,   815,   307,  3194,    13,  2102,    11,   612,   389,
#            257,  1271,   286,  1180,  2842,   284,   466,   428,    11,   290,
#            340,   318,  1593,   284,  1833,   644,  1123,   530,   286,   606,
#            318,   290,   703,   484, 15124,   284,  1123,   584,    13,   554,
#            428,  2708,    11,   356,   481,   804,   379,   617,   286,   262,
#            749,  2219,  2842,   287,   543,  3303,  4981,   460,  1037,   345,
#           1833,   703,  8950,   670,   290,   644,   484,  1612,   329,   345,
#             13, 50256]])

# %%
tokenizer.decode(output[0], skip_special_tokens=True)
# Out:
# 'What is Large Language Model?\n\nA large language model (MLM) is a set of rules that describe how a language should behave in a given context. MLMs are often used to describe the behavior of languages, but they can also be used for other purposes. For example, if you want to know how to write a sentence in English, you can use a MLM that describes how the sentence should be written. However, there are a number of different ways to do this, and it is important to understand what each one of them is and how they relate to each other. In this article, we will look at some of the most common ways in which language models can help you understand how languages work and what they mean for you.'
